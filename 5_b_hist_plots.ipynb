# %% [markdown]
# The basic operation of `plot` is extended with the `kind` parameter.  For example, here is a an example of a histogram.  Note that histogram will autmatically bucket the data for you!  Thus we automatically get a plot of the number of days with each level of rainfall.  So helpful.
#
# By the way, if you are interested in when to use a histogram vs when to use a bar graph - [this page has quite a nice explanation](https://www.storytellingwithdata.com/blog/2021/1/28/histograms-and-bar-charts)

# %%
import pandas as pd

rainfall = pd.read_csv("data/rainfall/IDCJAC0009_063292_1800_Data.csv")
choose_2022 = rainfall["Year"] == 2022
amount_2022 = rainfall[choose_2022]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True)
# Out:
# 10227    0.0
# 10228    0.0
# 10229    3.0
# 10230    0.0
# 10231    0.8
#         ...
# 10587    0.0
# 10588    0.0
# 10589    0.0
# 10590    2.2
# 10591    0.8
# Name: Rainfall amount (millimetres), Length: 365, dtype: float64
# <Axes: ylabel='Frequency'>

# %% [markdown]
# We should now be on-guard since a single extra parameter has done a power of work for us!  This is OK, but we must know that the `kind` parameter _can do data summarisation for us_.
#
# # Exercise - its all bunched up on the left!
#
# There are far too many 0mm rainfall days.  Can you create a similar bar plot which includes all years but excludes all days with 0mm of rain?
#
# How about greater than 10mm rain?  Greater than 40mm rain?  Discuss why you might consider `logy=True` and what that even means.  I don't know about you, but this fairly obvious pattern (when you think about it) was not obvious to me - the plot taught me something!

# %%
rainfall = pd.read_csv("data/rainfall/IDCJAC0009_063292_1800_Data.csv")
import matplotlib.pyplot as plt

mask_remove_zero = rainfall['Rainfall amount (millimetres)'] >= 0
amount_2022 = rainfall[mask_remove_zero]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True)
plt.show()

mask_remove_zero = rainfall['Rainfall amount (millimetres)'] >= 0
amount_2022 = rainfall[mask_remove_zero]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True, logy=True)
plt.show()

mask_remove_zero = rainfall['Rainfall amount (millimetres)'] > 0
amount_2022 = rainfall[mask_remove_zero]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True)
plt.show()

mask_over_10 = rainfall['Rainfall amount (millimetres)'] > 10
amount_2022 = rainfall[mask_over_10]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True)
plt.show()

mask_over_40 = rainfall['Rainfall amount (millimetres)'] > 40
amount_2022 = rainfall[mask_over_40]["Rainfall amount (millimetres)"]
display(amount_2022)
amount_2022.plot(kind="hist", legend=True)
plt.show()
# Out:
# 177       0.4
# 178       5.0
# 179       0.8
# 180       0.2
# 181       0.8
#          ...
# 10620     0.0
# 10621     3.8
# 10622    18.8
# 10623     0.0
# 10624     0.0
# Name: Rainfall amount (millimetres), Length: 10094, dtype: float64
# 177       0.4
# 178       5.0
# 179       0.8
# 180       0.2
# 181       0.8
#          ...
# 10620     0.0
# 10621     3.8
# 10622    18.8
# 10623     0.0
# 10624     0.0
# Name: Rainfall amount (millimetres), Length: 10094, dtype: float64
# 177       0.4
# 178       5.0
# 179       0.8
# 180       0.2
# 181       0.8
#          ...
# 10616     1.0
# 10618     4.2
# 10619     1.0
# 10621     3.8
# 10622    18.8
# Name: Rainfall amount (millimetres), Length: 5147, dtype: float64
# 292      15.0
# 332      16.0
# 342      34.0
# 358      15.0
# 359      20.0
#          ...
# 10596    13.8
# 10607    12.6
# 10610    13.2
# 10613    11.4
# 10622    18.8
# Name: Rainfall amount (millimetres), Length: 804, dtype: float64
# 384       46.0
# 428       67.0
# 429       54.0
# 632       69.0
# 704       58.0
#          ...
# 10324     68.0
# 10410    118.6
# 10411     91.0
# 10412     53.6
# 10544     53.2
# Name: Rainfall amount (millimetres), Length: 103, dtype: float64
